txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall13120.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall12494.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall01566.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall01748.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall05367.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall24133.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall15839.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall03939.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall02936.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall15649.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall20685.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall07059.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall+non-fall00785.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall22834.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall15050.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall10689.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall15860.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall14718.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall01055.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall19748.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall03126.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall01315.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall01635.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall21890.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall05023.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall10531.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall05349.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall22548.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall13261.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall12296.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/non-fall15564.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall04043.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/val/fall14204.txt
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/labels/.DS_Store
#   inflating: /content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/.DS_Store

# %% [markdown]
# ## Define Base Directory and Data Generator

# %%
BASE_DIR = "/content/Edge AI Fall detection/content/Edge AI Fall detection/Unwanted Removed/"

def data_generator(split='train', pref_size=(128, 128), batch_size=32):
    """
    Generator that yields batches of cropped images and class labels.

    Assumes folder structure:
      BASE_DIR/images/<split>/
      BASE_DIR/labels/<split>/

    For each image file, the generator reads the corresponding label file.
    For simplicity, it processes only the first bounding box per file.
    """
    img_dir = os.path.join(BASE_DIR, 'images', split)
    label_dir = os.path.join(BASE_DIR, 'labels', split)

    img_files = sorted(os.listdir(img_dir))
    label_files = sorted(os.listdir(label_dir))

    num_samples = len(img_files)

    while True:
        # Shuffle indices at the beginning of each epoch
        indices = np.arange(num_samples)
        np.random.shuffle(indices)
        for offset in range(0, num_samples, batch_size):
            batch_imgs = []
            batch_labels = []
            batch_indices = indices[offset:offset+batch_size]

            for idx in batch_indices:
                img_file = img_files[idx]
                label_file = label_files[idx]

                # Read the image and convert from BGR to RGB        
                img_path = os.path.join(img_dir, img_file)
                img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
                image_height, image_width, _ = img.shape

                label_path = os.path.join(label_dir, label_file)
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                if len(lines) == 0:
                    continue

                # Process only the first bounding box in the file
                line = lines[0]
                parts = line.split()
                if len(parts) < 5:
                    print(f"Warning: {label_file} does not have enough values: {line}")
                    continue
                class_label = int(parts[0])
                if len(parts) == 5:
                    # Standard YOLO format: <class> <x_center> <y_center> <width> <height>
                    x_center, y_center, width, height = map(float, parts[1:5])
                    xmin = int(x_center * image_width - (width * image_width) / 2)
                    ymin = int(y_center * image_height - (height * image_height) / 2)
                    crop_width = int(width * image_width)
                    crop_height = int(height * image_height)
                else:
                    # Extended format: <class> followed by multiple normalized coordinate pairs.
                    # Compute bounding box by taking the min and max of the coordinates.
                    coords = list(map(float, parts[1:]))
                    xs = [x * image_width for x in coords[0::2]]
                    ys = [y * image_height for y in coords[1::2]]
                    xmin, ymin = int(min(xs)), int(min(ys))
                    xmax, ymax = int(max(xs)), int(max(ys))
                    crop_width, crop_height = xmax - xmin, ymax - ymin

                # Ensure the crop indices are within image boundaries
                x_start, y_start = max(0, xmin), max(0, ymin)
                x_end, y_end = min(image_width, xmin + crop_width), min(image_height, ymin + crop_height)

                # Crop the image
                cropped = img[y_start:y_end, x_start:x_end]
                if cropped.size == 0:
                    print(f"Warning: empty crop for {img_file} with box {line}")
                    continue
                try:
                    # Resize crop to the preferred size
                    cropped_resized = cv2.resize(cropped, pref_size)
                except Exception as e:
                    print(f"Error resizing image {img_file}: {e}")
                    continue

                batch_imgs.append(cropped_resized)
                batch_labels.append(class_label)

            if batch_imgs:  
                X_batch = np.array(batch_imgs, dtype=np.float32) / 255.0
                y_batch = np.array(batch_labels)
                yield X_batch, y_batch

# %% [markdown]
# ## Create Dataset objects and Calculate Steps

# %%
def count_samples(split='train'):
    img_dir = os.path.join(BASE_DIR, 'images', split)
    return len(os.listdir(img_dir))

BATCH_SIZE = 32
train_samples = count_samples('train')
val_samples   = count_samples('val')
test_samples  = count_samples('test')

steps_per_epoch = int(np.ceil(train_samples / BATCH_SIZE))
val_steps       = int(np.ceil(val_samples / BATCH_SIZE))
test_steps      = int(np.ceil(test_samples / BATCH_SIZE))

print(f"Train samples: {train_samples}, Steps per epoch: {steps_per_epoch}")
print(f"Validation samples: {val_samples}, Validation steps: {val_steps}")
print(f"Test samples: {test_samples}, Test steps: {test_steps}")
# Out:
# Train samples: 23756, Steps per epoch: 743
# Validation samples: 6638, Validation steps: 208
# Test samples: 3340, Test steps: 105

# %% [markdown]
# ## Create Dataset objects from the generator for each split

# %%
train_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator('train', batch_size=BATCH_SIZE),
    output_types=(tf.float32, tf.int32),
    output_shapes=([None, 128, 128, 3], [None])
).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator('val', batch_size=BATCH_SIZE),
    output_types=(tf.float32, tf.int32),
    output_shapes=([None, 128, 128, 3], [None])
).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator('test', batch_size=BATCH_SIZE),
    output_types=(tf.float32, tf.int32),
    output_shapes=([None, 128, 128, 3], [None])
).prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:From <ipython-input-7-98ad6d5fe208>:2: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_types is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead
# WARNING:tensorflow:From <ipython-input-7-98ad6d5fe208>:2: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead

# %% [markdown]
# ## Build and Train the Model

# %%
# Load the MobileNetV2 base model with ImageNet weights
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze all layers first, then unfreeze the last 20 layers for fine-tuning
for layer in base_model.layers:
    layer.trainable = False
for layer in base_model.layers[-20:]:
    layer.trainable = True

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# Set up early stopping callback to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_128 (Functional)    │ (None, 4, 4, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,422,210 (9.24 MB)
#  Trainable params: 1,370,306 (5.23 MB)
#  Non-trainable params: 1,051,904 (4.01 MB)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    train_dataset,
    epochs=25,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_dataset,
    validation_steps=val_steps,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 683s 903ms/step - accuracy: 0.7017 - loss: 0.8249 - val_accuracy: 0.8499 - val_loss: 0.5813
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━
# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, label="Training Loss", marker='o')
plt.plot(val_loss, label="Validation Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_acc, label="Training Accuracy", marker='o')
plt.plot(val_acc, label="Validation Accuracy", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save the Model

# %%
model.save('/content/drive/MyDrive/Edge AI Fall detection/Roboflow/Fall-Detector.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Evaluate the Model on the Test Set

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, steps=test_steps)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 54s 481ms/step - accuracy: 0.9615 - loss: 0.3058
# Test Loss: 0.2929, Test Accuracy: 0.9659

# %% [markdown]
# ### Load the model

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Edge AI Fall detection/Roboflow/Fall-Detector.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Convert the Model to a Fully Quantized TFLite Model

# %%
def representative_dataset():
    image_size = (128, 128)
    samples = []

    # Take one batch from the test dataset for calibration  
    for X_batch, _ in test_dataset.take(1):
        for i in range(min(250, X_batch.shape[0])):
            # Convert the tensor to a numpy array and add a batch dimension
            sample = np.expand_dims(X_batch[i].numpy(), axis=0)
            samples.append(sample)
    for sample in samples:
        yield [sample]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Set the optimization flag to default; this enables quantization optimizations
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

# Set the input and output tensors to int8 for quantized inference
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
converter.representative_dataset = representative_dataset

tflite_quant_model = converter.convert()
with open("Fall-detector-lite.tflite", "wb") as f:
    f.write(tflite_quant_model)

print("Fully integer quantized TFLite model saved as 'fall_detection_int8.tflite'")
# Out:
# Saved artifact at '/tmp/tmpgd3zwzku'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   137175888896144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175888892304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175888893264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175888891920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175888893072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175888892496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866410384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866410768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866409232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866411920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866412304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866412688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866412496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866409040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866413840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866414224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866414608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866414416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866410000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866415760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866416144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866416528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866416336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866411536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866417680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866418064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866418448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866418256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866413456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866419600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866419984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866420368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866420176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866415376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866421520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866421904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866422288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866422096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866417296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866423440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866423824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866424208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866424016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866419216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866421136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866589648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866590224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866423056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866422672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866591184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866591568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866591952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866591760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866590416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866593104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866593872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866593680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866589456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866595408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866595792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866595600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866590800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866596944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866597328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866597712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866597520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866592720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866598864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866599632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866594640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866601168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866596560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866602704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866603280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866598480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866600400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175866602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908434384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908435152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908434192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908437264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908437648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908437456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908439568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908439376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908441104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908441488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908441296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908436496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908442640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908443408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908443216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908444560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908444944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908445328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908445136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908440336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908446480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908446864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908447248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908442256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908448400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908448784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908448976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908444176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908446096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908647952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908448016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908447632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908649680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908856080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908856848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908856656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908858000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908858384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908858768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908858576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908855696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909024208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909024784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908857616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175908857232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909025744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909026128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909026512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909024976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909025360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909035728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909036112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909035920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909037648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909038032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909037840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909038800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909038416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909039760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909036880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909353232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909352464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175909354384: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Fully integer quantized TFLite model saved as 'fall_detection_int8.tflite'

# %% [markdown]
# ## Load YOLOv5 for Detection

# %%
import torch

# Load YOLOv5 model for person detection
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
yolo_model.classes = [0]  # Restrict detections to person class
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv5 🚀 2025-4-6 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 102MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### Load the quantized TFLite model and allocate tensors

# %%
tflite_model_path = "/content/Fall-detector-lite.tflite"
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_scale, input_zero_point = input_details[0]['quantization']
output_scale, output_zero_point = output_details[0]['quantization']
pref_size = (128, 128)

# %% [markdown]
# ### Function to classify the image

# %%
def classify_crop(cropped_img):
    """
    Preprocess a cropped image and run classification using the TFLite model.
    Returns the predicted class and raw output.
    """
    # Convert image from BGR to RGB
    cropped_rgb = cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(cropped_rgb, pref_size)
    normalized = resized.astype(np.float32) / 255.0

    if input_scale != 0:
        quantized_input = normalized / input_scale + input_zero_point
        quantized_input = np.clip(quantized_input, -128, 127).astype(np.int8)
    else:
        quantized_input = normalized

    input_data = np.expand_dims(quantized_input, axis=0)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_details[0]['index'])

    if output_scale != 0:
        output_data = (output_data.astype(np.float32) - output_zero_point) * output_scale

    predicted_class = np.argmax(output_data)
    return predicted_class, output_data

# %% [markdown]
# ## Real-Time Fall Detection with TFLite Classifier

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

print("Starting real-time fall detection. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        break

    # Convert frame to RGB and create a PIL image for YOLO
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(frame_rgb)
    results = yolo_model(pil_img, size=640)
    df = results.pandas().xyxy[0]
    fall_detected = False

    for idx, row in df.iterrows():
        if row['confidence'] > 0.5:
            x1 = int(row['xmin'])
            y1 = int(row['ymin'])
            x2 = int(row['xmax'])
            y2 = int(row['ymax'])
            crop = frame[y1:y2, x1:x2]
            if crop.size == 0:
                continue

            pred, raw_output = classify_crop(crop)
            print(f"Raw output: {raw_output}, Predicted class: {pred}")

            if pred == 0:
                label_text = "Fall Detected"
                fall_detected = True
            else:
                label_text = "Non-Fall"

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label_text, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    if fall_detected:
        print("Fall detected in current frame!")

    cv2.imshow("Real-Time Fall Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
